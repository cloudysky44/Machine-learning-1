# %% [markdown]
# ### imports

# %%
import pandas as pd
# %cd /Machine-learning-1
import os
os.getcwd()
# Out:
# /Machine-learning-1
# '/Machine-learning-1'

# %% [markdown]
# ### datasets

# %%
df = pd.read_csv(r"data/melb_data.csv")

df2 = pd.read_csv(r"data/toy_dataset.csv")

# %% [markdown]
# ### testing
