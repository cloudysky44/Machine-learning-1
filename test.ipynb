# %% [markdown]
# ### imports

# %%
import pandas as pd

# %% [markdown]
# ### datasets

# %%
df = pd.read_csv("data/melb_data.csv")

df2 = pd.read_csv("data/toy_dataset.csv")

df3 = pd.read_csv("data/mobiles.csv")

df2 = df2.set_index("ID")

# %% [markdown]
# ### testing

# %%
df4 = df3.drop(columns=['url','Picture URL', '1 Stars', '2 Stars', '3 Stars', '4 Stars'])

# %%
df4
# Out:
#           Brand                                       Product Name  \
# 0          Vivo       Vivo V11 Pro (6GB RAM, 64GB) - Supernova Red
# 1          Vivo       Vivo V11 Pro (6GB RAM, 64GB) - Dazzling Gold
# 2          Vivo  Vivo V11 Pro (6GB RAM, 64GB) - Starry Night Black
# 3        Xiaomi             Redmi Note 5 Pro (4GB RAM, 64GB) - Red
# 4        Xiaomi       Redmi Note 5 Pro (6GB RAM, 64GB) - Rose Gold
# ...         ...                                                ...
# 8770     Realme                                                NaN
# 8771  Energizer                                                NaN
# 8772       Vivo                                                NaN
# 8773   Motorola                                                NaN
# 8774   Motorola                                                NaN
#
#                    Model  5 Stars Total Ratings Price in India  \
# 0                V11 Pro       70         6,534       ₹ 28,990
# 1                V11 Pro       70         6,534       ₹ 22,654
# 2                V11 Pro       70         6,534       ₹ 23,990
# 3       Redmi Note 5 Pro       65        13,009       ₹ 11,290
# 4       Redmi Note 5 Pro       65        13,009       ₹ 12,900
# ...                  ...      ...           ...            ...
# 8770               X Pro       75             4            NaN
# 8771  Power Max P18K Pop       33             6            NaN
# 8772           Apex 2019       75             4            NaN
# 8773             One Pro        0           NaN            NaN
# 8774            P40 Play        0           NaN            NaN
#
#       Battery capacity (mAh)         Processor Operating system  \
# 0                     3400.0         octa-core      Android 8.1
# 1                     3400.0         octa-core      Android 8.1
# 2                     3400.0         octa-core      Android 8.1
# 3                     4000.0  1.8GHz octa-core    Android 7.1.1
# 4                     4000.0  1.8GHz octa-core    Android 7.1.1
# ...                      ...               ...              ...
# 8770                     NaN         octa-core              NaN
# 8771                 18000.0               NaN              NaN
# 8772                     NaN               NaN              NaN
# 8773                     NaN               NaN          Android
# 8774                     NaN               NaN          Android
#
#                                             Rear camera  ...  \
# 0            12-megapixel (f/1.8) + 5-megapixel (f/2.4)  ...
# 1            12-megapixel (f/1.8) + 5-megapixel (f/2.4)  ...
# 2            12-megapixel (f/1.8) + 5-megapixel (f/2.4)  ...
# 3     12-megapixel (f/2.2, 1.25-micron) + 5-megapixe...  ...
# 4     12-megapixel (f/2.2, 1.25-micron) + 5-megapixe...  ...
# ...                                                 ...  ...
# 8770                                       48-megapixel  ...
# 8771           12-megapixel + 5-megapixel + 2-megapixel  ...
# 8772                                                Yes  ...
# 8773                                                Yes  ...
# 8774                                       13-megapixel  ...
#
#             Dimensions (mm)                            Colours  \
# 0     157.91 x 75.08 x 7.90        Dazzling Gold, Starry Black
# 1     157.91 x 75.08 x 7.90        Dazzling Gold, Starry Black
# 2     157.91 x 75.08 x 7.90        Dazzling Gold, Starry Black
# 3     158.60 x 75.40 x 8.05  Black, Blue, Gold, Red, Rose Gold
# 4     158.60 x 75.40 x 8.05  Black, Blue, Gold, Red, Rose Gold
# ...                     ...                                ...
# 8770                    NaN                                NaN
# 8771                    NaN                                NaN
# 8772                    NaN                                NaN
# 8773  158.70 x 75.00 x 8.80                                NaN
# 8774  147.70 x 71.50 x 9.20                                NaN
#
#      Expandable storage up to (GB)   FM  NFC  USB OTG Wi-Fi Direct  \
# 0                              256  Yes   No      Yes          Yes
# 1                              256  Yes   No      Yes          Yes
# 2                              256  Yes   No      Yes          Yes
# 3                              128  Yes   No      Yes          Yes
# 4                              128  Yes   No      Yes          Yes
# ...                            ...  ...  ...      ...          ...
# 8770                           NaN  NaN  NaN      NaN          NaN
# 8771                           NaN  NaN  NaN      NaN          NaN
# 8772                           NaN  NaN  NaN      NaN          NaN
# 8773                           NaN  NaN  NaN      NaN          NaN
# 8774                           NaN  NaN  NaN      NaN          NaN
#
#                Processor make Infrared  \
# 0     Qualcomm Snapdragon 660       No
# 1     Qualcomm Snapdragon 660       No
# 2     Qualcomm Snapdragon 660       No
# 3     Qualcomm Snapdragon 636       No
# 4     Qualcomm Snapdragon 636       No
# ...                       ...      ...
# 8770  Qualcomm Snapdragon 855      NaN
# 8771       MediaTek Helio P70      NaN
# 8772  Qualcomm Snapdragon 855      NaN
# 8773                      NaN      NaN
# 8774                      NaN      NaN
#
#                                              other_info
# 0     {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 1     {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 2     {'Weight (g)': '156.00', 'Sim 1 Supports 4G in...
# 3     {'Weight (g)': '181.00', 'Barometer': 'No', 'S...
# 4     {'Weight (g)': '181.00', 'Barometer': 'No', 'S...
# ...                                                 ...
# 8770  {'Total Ratings': '4', 'Rear autofocus': 'Yes'...
# 8771     {'Total Ratings': '6', 'Pop-Up Camera': 'Yes'}
# 8772  {'Total Ratings': '4', 'Launched in India': 'N...
# 8773                              {'USB Type-C': 'Yes'}
# 8774                                                 {}
#
# [8775 rows x 48 columns]
