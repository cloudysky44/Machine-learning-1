# %% [markdown]
# ### imports

# %%
import pandas as pd

# %% [markdown]
# ### datasets

# %%
df = pd.read_csv(r"data/melb_data.csv")

df2 = pd.read_csv(r"data/toy_dataset.csv")

# %% [markdown]
# ### testing

# %%
df2 = df2.set_index("ID")

df2
# Out:
#      Name  Age  Score       City
# ID
# 1   Aarav   16     85  Bengaluru
# 2    Diya   17     92     Mysuru
# 3   Rohan   16     78      Hubli
# 4   Sneha   18     88  Mangaluru
# 5   Kiran   17     81   Belagavi

# %%
# Out:
# ID
# 1    16
# 2    17
# 3    16
# 4    18
# 5    17
# Name: Age, dtype: int64
